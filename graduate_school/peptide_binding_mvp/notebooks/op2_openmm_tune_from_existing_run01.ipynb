# %% [markdown]
# # 옵션 2: openmm으로 ColabFold 복합체 PDB 포즈 튜닝 + 기존 파이프라인 Step4-최종 평가
# - 입력: 기존 pepbind_pipeline.py 실행 결과 폴더 (예: PDP_20251211_165304)
# - 출력: 같은 위치에 PDP_20251211_165304_op2_openmm_tuned 폴더 생성
# - 튜닝: openmm

# %%
# Cell 1) 기본 설정 (입력 폴더/출력 폴더/코드 경로)

from pathlib import Path
import shutil
import os

# 1) PepBind 베이스 경로 (네 환경에 맞게 수정 가능)
BASE_DIR = Path(os.environ.get("PEPBIND_BASE_DIR", "~/work/pipeline")).expanduser()

# 2) 기존 결과 워크스페이스 이름
SRC_WS = "PDP_20251222_162855"

# 3) 새로 만들 워크스페이스 이름(요청한 규칙)
DST_WS = f"{SRC_WS}_op2_openmm_tuned"

SRC_ROOT = BASE_DIR / SRC_WS
DST_ROOT = BASE_DIR / DST_WS

# 4) OpenMM 튜닝 기능이 들어있는 파이썬 코드 파일 경로
PIPELINE_PY_PATH = (BASE_DIR / "pepbind_pipeline_openmm06.py").expanduser()

print("BASE_DIR      =", BASE_DIR)
print("SRC_ROOT      =", SRC_ROOT)
print("DST_ROOT      =", DST_ROOT)
print("PIPELINE_PY   =", PIPELINE_PY_PATH)

if not SRC_ROOT.exists():
    raise FileNotFoundError(f"기존 워크스페이스 폴더가 없습니다: {SRC_ROOT}")

if not PIPELINE_PY_PATH.exists():
    raise FileNotFoundError(f"pepbind_pipeline_openmm06.py 파일이 없습니다: {PIPELINE_PY_PATH}")

if DST_ROOT.exists():
    print("기존 DST 폴더 삭제:", DST_ROOT)
    shutil.rmtree(DST_ROOT)
print("준비 완료")
# Out:
# BASE_DIR      = /home/aisys/work/pipeline
# SRC_ROOT      = /home/aisys/work/pipeline/PDP_20251222_162855
# DST_ROOT      = /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned
# PIPELINE_PY   = /home/aisys/work/pipeline/pepbind_pipeline_openmm06.py
# 준비 완료

# %%
# Cell 2) 워크스페이스 복제 (PDP_... → PDP_..._op2_openmm_tuned)

print("선택 복제 시작...")

# DST 워크스페이스 생성
DST_ROOT.mkdir(parents=True, exist_ok=False)

def copy_dir(src: Path, dst: Path):
    if not src.exists():
        print("스킵(없음):", src)
        return
    shutil.copytree(src, dst)
    print("복사(폴더):", src, "->", dst)

def copy_file(src: Path, dst: Path):
    if not src.exists():
        print("스킵(없음):", src)
        return
    dst.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(src, dst)
    print("복사(파일):", src, "->", dst)

# 최소 필수만 복사
copy_dir(SRC_ROOT / "fasta", DST_ROOT / "fasta")
copy_dir(SRC_ROOT / "pdb" / "colabfold_output", DST_ROOT / "pdb" / "colabfold_output")

# 있으면 batch_complexes.csv만 복사 (temp 폴더 전체는 복사하지 않음)
copy_file(SRC_ROOT / "temp" / "batch_complexes.csv", DST_ROOT / "temp" / "batch_complexes.csv")

# 혼동 방지: 결과 폴더는 새로 만들기(빈 폴더)
(DST_ROOT / "results" / "vina").mkdir(parents=True, exist_ok=True)
(DST_ROOT / "results" / "plip").mkdir(parents=True, exist_ok=True)
(DST_ROOT / "results" / "prodigy").mkdir(parents=True, exist_ok=True)

# refined 저장 위치도 미리 생성
(DST_ROOT / "pdb" / "refined").mkdir(parents=True, exist_ok=True)

print("선택 복제 완료:", DST_ROOT)
# Out:
# 선택 복제 시작...
# 복사(폴더): /home/aisys/work/pipeline/PDP_20251222_162855/fasta -> /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/fasta
# 복사(폴더): /home/aisys/work/pipeline/PDP_20251222_162855/pdb/colabfold_output -> /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/colabfold_output
# 복사(파일): /home/aisys/work/pipeline/PDP_20251222_162855/temp/batch_complexes.csv -> /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/temp/batch_complexes.csv
# 선택 복제 완료: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned

# %%
# Cell 3) 모듈 로드 (pepbind_pipeline_openmm02.py를 import해서 함수 재사용)
import importlib.util
import sys

spec = importlib.util.spec_from_file_location("pepbind_openmm02", str(PIPELINE_PY_PATH))
pep = importlib.util.module_from_spec(spec)
sys.modules["pepbind_openmm02"] = pep
spec.loader.exec_module(pep)

print("모듈 로드 완료:", pep.__name__)
# Out:
# [INFO] PyTorch device: cuda
# 모듈 로드 완료: pepbind_openmm02

# %%
# Cell 4) 출력 폴더 dict 구성 + (선택) 기존 평가 결과 폴더 정리
from pathlib import Path

folders = {
    "root": DST_ROOT,
    "fasta": DST_ROOT / "fasta",
    "pdb": DST_ROOT / "pdb",
    "colabfold_out": DST_ROOT / "pdb" / "colabfold_output",
    "results": DST_ROOT / "results",
    "vina": DST_ROOT / "results" / "vina",
    "plip": DST_ROOT / "results" / "plip",
    "prodigy": DST_ROOT / "results" / "prodigy",
    "temp": DST_ROOT / "temp",
}

for p in folders.values():
    if isinstance(p, Path):
        p.mkdir(parents=True, exist_ok=True)

print("폴더 준비 완료")
for k, v in folders.items():
    print(k, "=>", v)
# Out:
# 폴더 준비 완료
# root => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned
# fasta => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/fasta
# pdb => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb
# colabfold_out => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/colabfold_output
# results => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results
# vina => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina
# plip => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip
# prodigy => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/prodigy
# temp => /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/temp

# %%
# Cell 5) 기존 peptides 읽기 (peptides.fasta 또는 batch_complexes.csv)
def read_peptides_from_fasta(fa_path: Path):
    if not fa_path.exists():
        return []
    peptides = []
    seq = []
    with open(fa_path, "r") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            if line.startswith(">"):
                if seq:
                    peptides.append("".join(seq))
                    seq = []
            else:
                seq.append(line)
        if seq:
            peptides.append("".join(seq))
    return peptides

def read_peptides_from_batch_csv(csv_path: Path):
    if not csv_path.exists():
        return []
    import csv
    peptides = []
    with open(csv_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            seq = row["sequence"]
            # "target:peptide"
            if ":" in seq:
                pep_seq = seq.split(":")[1].strip()
                peptides.append(pep_seq)
    return peptides

pep_fasta = folders["fasta"] / "peptides.fasta"
batch_csv = folders["temp"] / "batch_complexes.csv"

peptides = read_peptides_from_fasta(pep_fasta)
if not peptides:
    peptides = read_peptides_from_batch_csv(batch_csv)

print("peptides 개수:", len(peptides))
print("peptides 예시:", peptides[:5])
if not peptides:
    raise RuntimeError("peptides를 읽지 못했습니다. peptides.fasta 또는 batch_complexes.csv를 확인하세요.")
# Out:
# peptides 개수: 20
# peptides 예시: ['AASL', 'LLIT', 'RVLA', 'GSVR', 'TSGE']

# %%
# Cell 6) rank_001 PDB 찾기 (기존 ColabFold 결과에서)
def find_rank1_pdbs(colabfold_out: Path):
    # 1) unrelaxed rank_001 우선
    p = sorted(colabfold_out.glob("*_unrelaxed_*rank_001*.pdb"))
    if p:
        return p
    # 2) fallback
    p = sorted(colabfold_out.glob("*rank_001*.pdb"))
    return p

rank1_pdbs = find_rank1_pdbs(folders["colabfold_out"])

print("rank_001 PDB 개수:", len(rank1_pdbs))
print("예시:", [x.name for x in rank1_pdbs[:3]])

if not rank1_pdbs:
    raise RuntimeError("ColabFold rank_001 PDB를 찾지 못했습니다. colabfold_output 폴더를 확인하세요.")
# Out:
# rank_001 PDB 개수: 20
# 예시: ['complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb', 'complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb', 'complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb']

# %%
# Cell 7) OpenMM 튜닝(구조 후처리) 실행 → refined PDB 생성
# 튜닝 파라미터 (원하는 값으로 조정 가능)
MD_TIME_PS  = 100.0
TIMESTEP_FS = 2.0
RESTRAINT_K = 1.0

refined_rank1_pdbs = pep.refine_structures_with_openmm_and_relax(
    rank1_pdbs,
    folders["pdb"],
    md_time_ps=MD_TIME_PS,
    timestep_fs=TIMESTEP_FS,
    restraint_k=RESTRAINT_K,
)

print("refined PDB 개수:", len(refined_rank1_pdbs))
print("refined 예시:", [x.name for x in refined_rank1_pdbs[:3]])
print("refined 폴더:", (folders["pdb"] / "refined"))
# Out:
# ================================================================================
# STEP 3b: 구조 후처리 (OpenMM minimization / short MD / Rosetta Relax)
# ================================================================================
#
# [REFINE] (1/20) complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (2/20) complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (3/20) complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [WARN] OpenMM 기반 refinement 실패, 원본 구조 유지: Particle position is NaN.  For more information, see https://github.com/openmm/openmm/wiki/Frequently-Asked-Questions#nan
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
#
# [REFINE] (4/20) complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (5/20) complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (6/20) complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (7/20) complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (8/20) complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (9/20) complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (10/20) complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (11/20) complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (12/20) complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (13/20) complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (14/20) complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (15/20) complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (16/20) complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (17/20) complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (18/20) complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (19/20) complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [REFINE] (20/20) complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] 입력 구조: complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [OpenMM] OXT 보정: 2개 residue에 OXT 추가 → complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000__openmm_prep.pdb
# [OpenMM] ForceField: amber14-all.xml + implicit/obc2.xml
# [OpenMM] Platform: CUDA
# [OpenMM] 에너지 minimization 수행 (maxIterations=2000)
# [OpenMM] short MD 수행: 100.0 ps, timestep=2.0 fs, steps=50000
# [OpenMM] refinement 완료 → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] RELAX_CMD 미설정 → Rosetta Relax 단계 스킵
# [REFINE] 최종 사용 구조: complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
#
# [INFO] 구조 후처리 완료. 총 20개 구조 반환.
# ================================================================================
# refined PDB 개수: 20
# refined 예시: ['complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb', 'complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb', 'complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb']
# refined 폴더: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined

# %%
# Cell 8) refined PDB 기준으로 Vina / PLIP / PRODIGY 재계산
# Vina
pep.run_vina_on_rank1(refined_rank1_pdbs, folders["vina"])
print("Vina 완료:", folders["vina"])

# PLIP
pep.run_plip_on_rank1(refined_rank1_pdbs, folders["plip"])
print("PLIP 완료:", folders["plip"])

# PRODIGY
pep.run_prodigy_on_rank1(refined_rank1_pdbs, folders["prodigy"])
print("PRODIGY 완료:", folders["prodigy"])
# Out:
# ================================================================================
# STEP 4: AutoDock Vina 도킹
# ================================================================================
#
# [INFO] Vina 준비: complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x 0.032 --center_y -20.198 --center_z -20.251 --size_x 19.105 --size_y 19.956 --size_z 18.321 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.043
#
# [INFO] Vina 준비: complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -5.771 --center_y -23.549 --center_z -19.915 --size_x 25.467 --size_y 20.013 --size_z 18.557 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -5.857
#
# [INFO] Vina 준비: complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb
# [INFO] complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_ligand_B.pdbqt --center_x -8.167 --center_y -25.830 --center_z -14.081 --size_x 21.535 --size_y 19.984 --size_z 21.078 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_vina_out.pdbqt
# [INFO] complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb Vina best score: -4.465
#
# [INFO] Vina 준비: complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -0.948 --center_y -17.770 --center_z -19.344 --size_x 19.975 --size_y 20.014 --size_z 15.661 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -7.641
#
# [INFO] Vina 준비: complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -5.948 --center_y -23.520 --center_z -19.384 --size_x 21.722 --size_y 20.030 --size_z 19.997 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.481
#
# [INFO] Vina 준비: complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -7.452 --center_y -23.368 --center_z -17.201 --size_x 20.669 --size_y 18.590 --size_z 19.103 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -5.361
#
# [INFO] Vina 준비: complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -7.856 --center_y -24.634 --center_z -15.467 --size_x 25.044 --size_y 18.071 --size_z 25.307 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -7.767
#
# [INFO] Vina 준비: complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -9.423 --center_y -24.298 --center_z -17.489 --size_x 19.205 --size_y 27.600 --size_z 20.931 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.749
#
# [INFO] Vina 준비: complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -8.422 --center_y -19.802 --center_z -13.160 --size_x 18.294 --size_y 19.166 --size_z 24.256 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -7.302
#
# [INFO] Vina 준비: complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -5.277 --center_y -22.549 --center_z -19.760 --size_x 23.427 --size_y 20.918 --size_z 15.570 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -5.635
#
# [INFO] Vina 준비: complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -8.089 --center_y -23.701 --center_z -17.211 --size_x 19.521 --size_y 17.517 --size_z 19.938 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -5.162
#
# [INFO] Vina 준비: complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x 1.174 --center_y 16.944 --center_z 22.355 --size_x 22.704 --size_y 18.062 --size_z 20.917 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.707
#
# [INFO] Vina 준비: complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -5.559 --center_y -22.807 --center_z -21.030 --size_x 20.719 --size_y 21.120 --size_z 18.284 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -5.424
#
# [INFO] Vina 준비: complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -8.301 --center_y -24.530 --center_z -15.708 --size_x 23.284 --size_y 18.051 --size_z 20.278 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.502
#
# [INFO] Vina 준비: complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -5.359 --center_y -19.659 --center_z -20.558 --size_x 18.303 --size_y 22.724 --size_z 16.676 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.288
#
# [INFO] Vina 준비: complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -7.103 --center_y -17.472 --center_z -19.649 --size_x 19.202 --size_y 21.573 --size_z 15.993 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.251
#
# [INFO] Vina 준비: complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -6.084 --center_y -21.058 --center_z -19.297 --size_x 24.780 --size_y 22.135 --size_z 16.342 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.397
#
# [INFO] Vina 준비: complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -7.457 --center_y -24.630 --center_z -17.655 --size_x 21.926 --size_y 19.016 --size_z 19.673 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -6.204
#
# [INFO] Vina 준비: complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdb -xr -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt
# [RUN] /home/aisys/miniconda3/envs/pepbind_openmm/bin/obabel -ipdb /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdb -opdbqt -O /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B_raw.pdbqt
# [RUN] vina --receptor /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_receptor_A.pdbqt --ligand /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_ligand_B.pdbqt --center_x -9.433 --center_y 9.440 --center_z 0.898 --size_x 16.305 --size_y 18.823 --size_z 25.710 --out /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined_vina_out.pdbqt
# [INFO] complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb Vina best score: -11.71
#
# [INFO] Vina 준비: complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb
# [INFO] complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb 체인 구성: {'A': 222, 'B': 4}
# [INFO] 자동 할당 체인: receptor=A, ligand=B
# ...
# ✔️ PLIP 완료: complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
# [RUN] plip -f /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb -o /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined -x -t --chains [['A'], ['B']]
# ✔️ PLIP 완료: complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb → /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined
#
# [INFO] PLIP 실행 디버그 로그: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/plip_run_debug.txt
# [INFO] PLIP 파싱 디버그 로그: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/plip_parse_debug.txt
# [INFO] PLIP 요약 엑셀 저장: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/plip_summary.xlsx
# [INFO] PLIP 상호작용을 읽어온 구조 수: 20
# ================================================================================
# PLIP 완료: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip
#
# ================================================================================
# STEP 6: PRODIGY 결합 친화도 평가
# ================================================================================
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_0_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_10_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/colabfold_output/complex_11_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_12_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_13_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_14_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_15_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_16_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_17_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_18_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_19_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_1_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_2_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_3_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_4_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_5_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_6_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_7_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_8_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [RUN] prodigy /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/pdb/refined/complex_9_unrelaxed_rank_001_alphafold2_multimer_v3_model_1_seed_000_openmm_refined.pdb --selection A B
# [INFO] PRODIGY 디버그 로그: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/prodigy/prodigy_debug.txt
# ✅ PRODIGY 요약 엑셀 저장: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/prodigy/prodigy_summary.xlsx
# PRODIGY 완료: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/prodigy

# %%
# Cell 9) 최종 산출물 생성 (PDB zip + 최종 엑셀)
from datetime import datetime

# (선택) refined pdb zip
pdb_zip = pep.zip_rank1_pdbs(refined_rank1_pdbs, folders["results"])
print("PDB zip:", pdb_zip)

# 최종 엑셀
final_xlsx = pep.build_and_save_final_table(
    folders=folders,
    peptides=peptides,
    rank1_pdbs=refined_rank1_pdbs,
    start_time=None,
    end_time=None,
    step_timings=None,
)
print("최종 엑셀:", final_xlsx)

print("\n완료. 결과 워크스페이스:", DST_ROOT)
# Out:
# ✅ rank_001 PDB 압축 저장: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/peptide_structures_20251222_175254.zip
# PDB zip: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/peptide_structures_20251222_175254.zip
# [INFO] Vina 요약 엑셀에서 점수 로드: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/vina/vina_summary.xlsx
# [INFO] Vina 점수를 읽어온 구조 수: 20
# [INFO] PRODIGY 요약 엑셀에서 점수 로드: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/prodigy/prodigy_summary.xlsx
# [INFO] PRODIGY ΔG를 요약 파일에서 불러옴: 20개 구조
# [INFO] ipTM 값을 읽어온 구조 수: 39 / 20
# [INFO] PLIP 파싱 디버그 로그: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/plip_parse_debug.txt
# [INFO] PLIP 요약 엑셀 저장: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/plip/plip_summary.xlsx
# [INFO] PLIP 상호작용을 읽어온 구조 수: 20
# ✅ 최종 결과 엑셀 저장: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/final_peptide_rank_20251222_175255.xlsx
# 최종 엑셀: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned/results/final_peptide_rank_20251222_175255.xlsx
#
# 완료. 결과 워크스페이스: /home/aisys/work/pipeline/PDP_20251222_162855_op2_openmm_tuned
