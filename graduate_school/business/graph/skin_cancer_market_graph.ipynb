# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import subprocess

# --- 1. 한글 폰트 설치 (가장 중요!) ---
# 'ds_python_interpreter' 환경에서 나눔 폰트 설치
# subprocess.run(['apt-get', 'install', '-y', 'fonts-nanum'])

# 폰트 매니저에 나눔 폰트 경로 추가 및 캐시 재생성
# for font in fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum']):
#     fm.fontManager.addfont(font)
# fm._rebuild() # 폰트 캐시 재생성

# Matplotlib의 기본 폰트를 'NanumGothic'으로 설정
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지
# ------------------------------------
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import matplotlib.font_manager as fm
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'
